# %% [markdown]
# Basic Print

# %%
print('hello world')
# Out:
# hello world

# %%
print(4)
# Out:
# 4

# %%
print(True)
# Out:
# True

# %%
print('Hello',5.6,True)
# Out:
# Hello 5.6 True

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %%
print('hello',end=' ')
print('world')
# Out:
# hello world

# %% [markdown]
# Data Type

# %%
#Integer
print(1e309)
# Out:
# inf

# %%
#Decimal/Float
print(1.7e309)
# Out:
# inf

# %%
#Text/String
print('Hello world')
# Out:
# Hello world

# %%
#Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
#Complex
print(5+6j)
# Out:
# (5+6j)

# %%
#list
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#Tuple
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
#Sets
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#Dictionary
print({'Name':'Jemima','Gender':'Female','Age':'21'})
# Out:
# {'Name': 'Jemima', 'Gender': 'Female', 'Age': '21'}

# %%
#Type
type([1,2,3,6])
# Out:
# list

# %% [markdown]
# Variables

# %%
from typing_extensions import NamedTuple
name='Jemima'
print(name)
# Out:
# Jemima

# %%
age=6
print(age)
# Out:
# 6

# %%
a=2
b=3
print(a+b)
# Out:
# 5

# %%
#Dynamic Typing
a=3
#Dynamic Typing
a=3
print(a)
#Static Typing
#int a=5
a=5
print(a)
# Out:
# 3
# 5

# %%
#Dynamic Binding(its for python becuase python is more powerful.it can dectect data type itself.so any value can be stored in one variale)
a='jemima'
print(a)
a=4
print(a)
#static Binding(it works on c/c++.when we declare data type then only that type of data can be stored.this diference between dyn. binding and sta. binding)
#int a
a=4
print(a)
a=6
print(a)
# Out:
# jemima
# 4

# %%
a=b=c=4
print(a,b,c)
# Out:
# 4 4 4

# %%
a,b,c=1,2,3
print(a,b,c)
# Out:
# 1 2 3

# %%
#defferences between intepretor and compiler-interpretor convert whole code and compilerconvert one by one.

# %%
#keyword-resrved word in python.identifier-the name given by programmer

# %% [markdown]
# Type conversion

# %%
a=2
b=5
print(a+b)
#implicit
# Out:
# 7

# %%
a=input('a=')
b=input('b=')
print(a+b)
#here implicit that means self datatype conversion is not working.they are in string.so they just added sidebyside.so we need to do expicit
# Out:
# a=4
# b=6
# 46

# %%
a=input('a=')
b=input('b=')
print(int(a+b))
type(a)
#still it is string,since we convert after keeping the vale in variaable
# Out:
# a=4
# b=5
# 45
# str

# %%
a=int(input('a='))
b=int(input('b='))
print(a+b)
type(a)
#but there it is int,becuse we have convert data type before keeping in variable.
# Out:
# a=5
# b=6
# 11
# int

# %% [markdown]
# literal

# %%
from ast import literal_eval
a=0b1011#binary
b=0o16#octal
c=0x16#hexadecimal
print(a,b,c)


#float literal
float_1=10.5
float_2=1.5e19
float_3=1.5e-2
print(float_1,float_2,float_3)

#complex literal
a=5+3.14j
print(a)
print(a.imag,a.real)
# Out:
# 11 14 22
# 10.5 1.5e+19 0.015
# (5+3.14j)
# 3.14 5.0

# %%
#string
a='jemima'
b="jemima"
c="""I am jemima.Im 16 years old.I love cooking.I have also other hobby."""#triple inverted comma for multiple line
print(a,b,c)
# Out:
# jemima jemima I am jemima.Im 16 years old.I love cooking.I have also other hobby.

# %%
a=True+2
b=False+4
print(a,b)
# Out:
# 3 4

# %%
k=None
a=3
c=4
print(a+c)
# Out:
# 7
