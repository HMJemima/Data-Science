# %%
#Continue
for i in range(1,11):
  if i==5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
#pass
for i in range(1,11):
  pass

# %% [markdown]
# Stingsssssss

# %%
print('Jemima')
print(" 'jemima' ")
#for multiple lines
print(""" jemima""")
print('''Jemima''')
s=str('jemima')
print(s)
# Out:
# Jemima
#  'jemima'
#  jemima
# Jemima
# jemima

# %%
#positive indexing-starts from the fisrt
s=str('hello world')
print(s[10])
# Out:
# d

# %%
#negative  indexing-starts from the ending
s=str('hello world')
print(s[-1])
# Out:
# d

# %%
#slicing
s=str('hello world')
print(s[0:4])
# Out:
# hell

# %%
#slicing
s=str('hello world')
print(s[0:6:2])
# Out:
# hlo

# %%
#slicing
s=str('hello world')
print(s[3:])
# Out:
# lo world

# %%
#slicing
s=str('hello world')
print(s[6::-1])
# Out:
# w olleh

# %%
s=str('hello world')
print(s[::-1])
# Out:
# dlrow olleh

# %%
s=str('hello world')
print(s[-5::1])
# Out:
# world

# %% [markdown]
# string Editing is not possible.

# %%
#del
s=str('hello world')
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-43-3872778472.py in <cell line: 0>()
#       2 s=str('hello world')
#       3 del s
# ----> 4 print(s)
#
# NameError: name 's' is not defined

# %%
#del
s=str('hello world')
del s[-1:-5:1]
print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-44-3313954401.py in <cell line: 0>()
#       1 #del
#       2 s=str('hello world')
# ----> 3 del s[-1:-5:1]
#       4 print(s)
#
# TypeError: 'str' object does not support item deletion

# %% [markdown]
# string Operation
#
#
#
# *  arithmatic operation
# *  relaational operation
# *   Logical operation
# *   Loop on string
# *   membership operation
#
#
#
#
#
#
#
# ---

# %%
#arithmatic
print('hello'+'world')
# Out:
# helloworld

# %%
print('str'*5)
# Out:
# strstrstrstrstr

# %%
'Dhaka'=='Khulna'
# Out:
# False

# %%
'Dhaka'=='Dhaka'
# Out:
# True

# %%
'Dhaka'>'Khulna'
# Out:
# False

# %%
'Dhaka'<'dhaka'
# Out:
# True

# %%
'Dhaka'and'khulna'
# Out:
# 'khulna'

# %%
'Dhaka'or'khulna'
# Out:
# 'Dhaka'

# %%
not 'hello'
# Out:
# False

# %%
for i in 'hello':
  print(i)
# Out:
# h
# e
# l
# l
# o

# %%
for i in 'hello':
  print('jemima')
# Out:
# jemima
# jemima
# jemima
# jemima
# jemima

# %%
'D' in 'delhi'
# Out:
# False

# %% [markdown]
# common function
#
# *   len
# *   max
#
# *   min
# *   sorted

# %%
len('hello world')
# Out:
# 11

# %%
max('hello world')
# Out:
# 'w'

# %%
min('hello world')
# Out:
# ' '

# %%
sorted('hello world')
# Out:
# [' ', 'd', 'e', 'h', 'l', 'l', 'l', 'o', 'o', 'r', 'w']

# %% [markdown]
# capitalize/upper/lower/swap/title

# %%
s='hello world'
s.capitalize()
# Out:
# 'Hello world'

# %%
s.title()
# Out:
# 'Hello World'

# %%
'Jemima'.lower()
# Out:
# 'jemima'

# %%
s.swapcase()
# Out:
# 'HELLO WORLD'

# %% [markdown]
# count/find/index

# %%
'My name is jemima'.find('is')
# Out:
# 8

# %%
'My name is jemima'.index('is')
# Out:
# 8

# %%
'My name is jemima'.find('x')
# Out:
# -1

# %%
'My name is jemima'.index(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-91-3453397091.py in <cell line: 0>()
# ----> 1 'My name is jemima'.index(x)
#
# NameError: name 'x' is not defined

# %%
'My name is jemima'.count('m')
# Out:
# 3

# %% [markdown]
# Endswith/*startswith*

# %%
'my name is Jemima'.endswith('Jemima')
# Out:
# True

# %%
'my name is Jemima'.startswith('my')
# Out:
# True

# %% [markdown]
# Format

# %%
n=input('enter ur nm')
g=input('enter ur gender')
print('my name is {0} and Im {1}'.format(n,g))
# Out:
# enter ur nmJemima
# enter ur genderfemale
# my name isJemima and Im female
